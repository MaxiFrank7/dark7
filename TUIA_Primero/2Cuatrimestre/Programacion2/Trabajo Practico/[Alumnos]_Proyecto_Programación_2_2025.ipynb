# %% [markdown]
# ## **Trabajo Práctico: La Gran Prueba de Sabor**

# %% [markdown]
# **Apellido y Nombres de los Integrantes del grupo:**
#
#
# 1. XXXXX, XXXXXXX
# 2. XXXXX, XXXXXXX
# 3. XXXXX, XXXXXXX
# 4. XXXXX, XXXXXXX

# %% [markdown]
# # **Presentación**

# %% [markdown]
# **Una consultora** ha sido contratada para realizar un **análisis de mercado** y **proporcionar recomendaciones estratégicas** para la apertura de una cafetería en EE.UU.
#
# Se le solicitó llevar a cabo un estudio utilizando los datos de la encuesta [**"La Gran Prueba de Sabor"**](https://raw.githubusercontent.com/rfordatascience/tidytuesday/refs/heads/main/data/2024/2024-05-14/coffee_survey.csv), con el fin de extraer información sobre las preferencias de los consumidores y ayudar al grupo inversor a diseñar una estrategia informada para su incursión en el sector. Esta encuesta la realizó el famoso barista *James Hoffmann* en octubre de 2023, durante una transmisión en vivo con unas *4.000 personas* en Estados Unidos.

# %% [markdown]
# #**Objetivo del Proyecto Final**

# %% [markdown]
# En este Proyecto Final, el alumno asumirá el rol de consultor. Para la lectura, manipulación y análisis de los datos de la encuesta se debe usar el paquete Pandas.

# %% [markdown]
# #**Consignas**

# %% [markdown]
# 1. Descargar el archivo de la encuesta ejecutando el código que se propone a continuación.

# %%
#No modificar este código que le permitirá bajar el archivo que necesita para trabajar

import requests

url_coffee_survey = "https://raw.githubusercontent.com/rfordatascience/tidytuesday/refs/heads/main/data/2024/2024-05-14/coffee_survey.csv"
archivo_salida_coffee_survey = "coffee_survey.csv"

def descargarCSV(url, archivo_salida):
    print("Descargando archivo...")
    consulta = requests.get(url)
    contenido = consulta.content

    print("Guardando archivo...")
    # Abrir conexion en modo escritura
    with open(archivo_salida, "w", encoding="utf-8") as archivo:
        # Escribir el contenido de la consulta
        archivo.write(contenido.decode("utf-8"))

    print("¡Archivo descargado con éxito!")

descargarCSV(url_coffee_survey,archivo_salida_coffee_survey)
# Out:
# Descargando archivo...
# Guardando archivo...
# ¡Archivo descargado con éxito!

# %% [markdown]
# 2. Una vez descargado el archivo analice su contenido. ¿Qué información brinda de cada persona encuestada? ¿Todos los encuestados respondieron a todas las preguntas?
#
# 3. Explore libremente los datos utilizando Pandas.

# %%
import pandas as pd

df = pd.read_csv('coffee_survey.csv')

df.head()

df['age']

df['additions']

df.info()

df.tail(10)

df.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4042 entries, 0 to 4041
# Data columns (total 57 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   submission_id                 4042 non-null   object
#  1   age                           4011 non-null   object
#  2   cups                          3949 non-null   object
#  3   where_drink                   3972 non-null   object
#  4   brew                          3657 non-null   object
#  5   brew_other                    678 non-null    object
#  6   purchase                      710 non-null    object
#  7   purchase_other                31 non-null     object
#  8   favorite                      3980 non-null   object
#  9   favorite_specify              114 non-null    object
#  10  additions                     3959 non-null   object
#  11  additions_other               48 non-null     object
#  12  dairy                         1686 non-null   object
#  13  sweetener                     512 non-null    object
#  14  style                         3958 non-null   object
#  15  strength                      3916 non-null   object
#  16  roast_level                   3940 non-null   object
#  17  caffeine                      3917 non-null   object
#  18  expertise                     3938 non-null   float64
#  19  coffee_a_bitterness           3798 non-null   float64
#  20  coffee_a_acidity              3779 non-null   float64
#  21  coffee_a_personal_preference  3789 non-null   float64
#  22  coffee_a_notes                2578 non-null   object
#  23  coffee_b_bitterness           3780 non-null   float64
#  24  coffee_b_acidity              3767 non-null   float64
#  25  coffee_b_personal_preference  3773 non-null   float64
#  26  coffee_b_notes                2454 non-null   object
#  27  coffee_c_bitterness           3764 non-null   float64
#  28  coffee_c_acidity              3751 non-null   float64
#  29  coffee_c_personal_preference  3766 non-null   float64
#  30  coffee_c_notes                2382 non-null   object
#  31  coffee_d_bitterness           3767 non-null   float64
#  32  coffee_d_acidity              3765 non-null   float64
#  33  coffee_d_personal_preference  3764 non-null   float64
#  34  coffee_d_notes                2588 non-null   object
#  35  prefer_abc                    3772 non-null   object
#  36  prefer_ad                     3761 non-null   object
#  37  prefer_overall                3770 non-null   object
#  38  wfh                           3524 non-null   object
#  39  total_spend                   3511 non-null   object
#  40  why_drink                     3568 non-null   object
#  41  why_drink_other               167 non-null    object
#  42  taste                         3563 non-null   object
#  43  know_source                   3559 non-null   object
#  44  most_paid                     3527 non-null   object
#  45  most_willing                  3510 non-null   object
#  46  value_cafe                    3500 non-null   object
#  47  spent_equipment               3506 non-null   object
#  48  value_equipment               3494 non-null   object
#  49  gender                        3523 non-null   object
#  50  gender_specify                12 non-null     object
#  51  education_level               3438 non-null   object
#  52  ethnicity_race                3418 non-null   object
#  53  ethnicity_race_specify        105 non-null    object
#  54  employment_status             3419 non-null   object
#  55  number_children               856 non-null    object
#  56  political_affiliation         3289 non-null   object
# dtypes: float64(13), object(44)
# memory usage: 1.8+ MB
# (4042, 57)

# %% [markdown]
#   Ahora haremos una **exploración guiada de la encuesta utilizando `Pandas`**. En los siguientes ejercicios no puede usar estructuras de repetición (`for`, `while`, etc), salvo que el enunciado indique explícitamente lo contrario.

# %% [markdown]
# 4. Cargue la información del archivo *coffee_survey.csv* en un `DataFrame` llamado `encuesta`.
# 5. Utilice el método `info` sobre el `DataFrame` cargado con los datos de la encuesta. ¿Qué información importante nos brinda este método sobre los datos recién cargados? Comente.

# %%
import pandas as pd

# 4. Cargar los datos
encuesta = pd.read_csv('coffee_survey.csv')

# 5. Invocar al método info
encuesta.info
# Out:
# <bound method DataFrame.info of      submission_id              age cups  \
# 0           gMR29l  18-24 years old  NaN
# 1           BkPN0e  25-34 years old  NaN
# 2           W5G8jj  25-34 years old  NaN
# 3           4xWgGr  35-44 years old  NaN
# 4           QD27Q8  25-34 years old  NaN
# ...            ...              ...  ...
# 4037        PA44VP    >65 years old    2
# 4038        vNgpPD    >65 years old    2
# 4039        g5ggRM  18-24 years old    1
# 4040        rlgbDN  25-34 years old    2
# 4041        0EGYe9  25-34 years old    1
#
#                                        where_drink  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
# ...                                            ...
# 4037                                       At home
# 4038                                       At home
# 4039  At a cafe, At home, On the go, At the office
# 4040                                       At home
# 4041                                       At home
#
#                                                    brew brew_other  \
# 0                                                   NaN        NaN
# 1           Pod/capsule machine (e.g. Keurig/Nespresso)        NaN
# 2                                   Bean-to-cup machine        NaN
# 3              Coffee brewing machine (e.g. Mr. Coffee)        NaN
# 4                                             Pour over        NaN
# ...                                                 ...        ...
# 4037           Coffee brewing machine (e.g. Mr. Coffee)        NaN
# 4038           Coffee brewing machine (e.g. Mr. Coffee)        NaN
# 4039  Espresso, Pod/capsule machine (e.g. Keurig/Nes...  Aeropress
# 4040                                          Pour over        NaN
# 4041           Pour over, French press, Espresso, Other  Aeropress
#
#                                                purchase purchase_other  \
# 0                                                   NaN            NaN
# 1                                                   NaN            NaN
# 2                                                   NaN            NaN
# 3                                                   NaN            NaN
# 4                                                   NaN            NaN
# ...                                                 ...            ...
# 4037                                                NaN            NaN
# 4038                                                NaN            NaN
# 4039  National chain (e.g. Starbucks, Dunkin), Drive...            NaN
# 4040                                                NaN            NaN
# 4041                                                NaN            NaN
#
#                  favorite favorite_specify  ... spent_equipment  \
# 0     Regular drip coffee              NaN  ...             NaN
# 1             Iced coffee              NaN  ...             NaN
# 2     Regular drip coffee              NaN  ...             NaN
# 3             Iced coffee              NaN  ...             NaN
# 4                   Latte              NaN  ...             NaN
# ...                   ...              ...  ...             ...
# 4037  Regular drip coffee              NaN  ...   Less than $20
# 4038  Regular drip coffee              NaN  ...   Less than $20
# 4039                Latte              NaN  ...       $300-$500
# 4040          Iced coffee              NaN  ...       $100-$300
# 4041                Latte              NaN  ...      $500-$1000
#
#      value_equipment  gender gender_specify  \
# 0                NaN     NaN            NaN
# 1                NaN     NaN            NaN
# 2                NaN     NaN            NaN
# 3                NaN     NaN            NaN
# 4                NaN     NaN            NaN
# ...              ...     ...            ...
# 4037             Yes  Female            NaN
# 4038             Yes    Male            NaN
# 4039             Yes    Male            NaN
# 4040             Yes    Male            NaN
# 4041             Yes  Female            NaN
#
#                          education_level   ethnicity_race  \
# 0                                    NaN              NaN
# 1                                    NaN              NaN
# 2                                    NaN              NaN
# 3                                    NaN              NaN
# 4                                    NaN              NaN
# ...                                  ...              ...
# 4037                     Master's degree  White/Caucasian
# 4038                   Bachelor's degree  White/Caucasian
# 4039  Some college or associate's degree  White/Caucasian
# 4040                   Bachelor's degree  White/Caucasian
# 4041    Doctorate or professional degree  White/Caucasian
#
#      ethnicity_race_specify   employment_status  number_children  \
# 0                       NaN                 NaN              NaN
# 1                       NaN                 NaN              NaN
# 2                       NaN                 NaN              NaN
# 3                       NaN                 NaN              NaN
# 4                       NaN                 NaN              NaN
# ...                     ...                 ...              ...
# 4037                    NaN             Retired                2
# 4038                    NaN             Retired                2
# 4039                    NaN  Employed full-time              NaN
# 4040                    NaN          Unemployed              NaN
# 4041                    NaN  Employed full-time                1
#
#       political_affiliation
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
# ...                     ...
# 4037               Democrat
# 4038             Republican
# 4039               Democrat
# 4040               Democrat
# 4041               Democrat
#
# [4042 rows x 57 columns]>

# %% [markdown]
# Haga aquí sus comentarios sobre la información devuelta por el método `info`: *completar*

# %% [markdown]
# 6. Analice la columna *'age'* que indica el rango de edad del encuestado. ¿Qué cantidad de los encuestados que brindaron esta información pertenecen a los rangos *'<18 years old'*, *'18-24 years old'*, *'25-34 years old'*, *'35-44 years old'*, *'45-54 years old'*, *'55-64 years old'* y *'>65 years old'*, respectivamente? Ignore los valores *'NA'*.

# %%
# 6. Analizar la columna 'age'
encuesta.groupby('age').size()
# Out:
# age
# 18-24 years old     461
# 25-34 years old    1986
# 35-44 years old     960
# 45-54 years old     302
# 55-64 years old     187
# <18 years old        20
# >65 years old        95
# dtype: int64

# %% [markdown]
# 7. Analice la columna 'where_drink' que indica dónde toman café los encuestados. ¿Qué diferencia encuentra entre esta columna de la anterior? ¿Qué cantidad de los encuestados que respondieron a esta pregunta toman el café *'On the go'*, *'At a cafe'*, *'At the office'*, *'At home'*, *'None of these'*, respectivamente? Ignore los valores *'NA'*.
#
#     **Ayuda**: investigue el método  `explode`.

# %%
# 7. Analizar la columna 'where_drink'
# Out:
# Conteo de lugares de consumo:
#  where_drink
# At home          3644
# At the office    1430
# At a cafe        1170
# On the go         705
# None of these      36
# Name: count, dtype: int64

# %% [markdown]
# 8. Analice los códigos propuestos para responder a las consignas 6. y 7. Son similares, ¿verdad? Proponga una función `procesar_columna`, que recibiendo el `DataFrame` y el nombre de la columna a analizar, sirva para resolver los dos casos anteriores.

# %%
# 8. Función para procesar cualquier columna
def procesar_columna(dataframe, columna):
  pass

# %% [markdown]
# 9. Pruebe la función anterior, analizando las columnas *'gender'* y *'cups'*. ¿Funciona?

# %%
# 9. Pruebas de la función
# Out:
# Conteo de cups:
#  gender
# Male                      2524
# Female                     853
# Non-binary                 103
# Prefer not to say           33
# Other (please specify)      10
# Name: count, dtype: int64
# Conteo de brew:
#  cups
# 2              1663
# 1              1277
# 3               473
# Less than 1     348
# 4               121
# More than 4      67
# Name: count, dtype: int64

# %% [markdown]
# 10. Implemente una función llamada `filtrar_columna_valor` que reciba un `DataFrame`, el nombre de una columna y un valor para dicha columna como argumentos. La función debe filtrar las filas, devolviendo sólo aquellas que hayan pasado el filtro aplicado. Hacer dos pruebas, filtrando por `gender` igual a `Female` y `gender` igual a `Male`. Mostrar en pantalla los primeros 5 registros de cada resultado obtenido.

# %%
# 10. Filtrar encuesta
def filtrar_columna_valor(dataframe, columna, valor):
  pass
# Out:
#    submission_id              age         cups  \
# 17        QA5JYA  25-34 years old            1
# 53        WApbYk  35-44 years old            1
# 63        NABN5G  45-54 years old  More than 4
# 78        vNx8Xv  35-44 years old            1
# 82        7d97lZ  25-34 years old            2
#
#                           where_drink  \
# 17  At home, At the office, On the go
# 53             At the office, At home
# 63                            At home
# 78                            At home
# 82             At home, At the office
#
#                                                  brew brew_other  \
# 17  Pour over, Coffee brewing machine (e.g. Mr. Co...        NaN
# 53                                              Other  Aeropress
# 63  Pod/capsule machine (e.g. Keurig/Nespresso), O...  Aeropress
# 78                                       French press        NaN
# 82                     Coffee extract (e.g. Cometeer)        NaN
#
#                                              purchase purchase_other  \
# 17  National chain (e.g. Starbucks, Dunkin), Local...            NaN
# 53                                                NaN            NaN
# 63                                                NaN            NaN
# 78                                                NaN            NaN
# 82                                                NaN            NaN
#
#                favorite favorite_specify  ... spent_equipment value_equipment  \
# 17  Regular drip coffee              NaN  ...             NaN             NaN
# 53            Americano              NaN  ...       $100-$300             Yes
# 63            Americano              NaN  ...       $100-$300             Yes
# 78            Cold brew              NaN  ...        $50-$100             Yes
# 82            Americano              NaN  ...         $20-$50              No
#
#     gender gender_specify                   education_level  \
# 17  Female            NaN                 Bachelor's degree
# 53  Female            NaN                 Bachelor's degree
# 63  Female            NaN                               NaN
# 78  Female            NaN                 Bachelor's degree
# 82  Female            NaN  Doctorate or professional degree
#
#             ethnicity_race ethnicity_race_specify   employment_status  \
# 17         White/Caucasian                    NaN  Employed full-time
# 53         White/Caucasian                    NaN  Employed full-time
# 63                     NaN                    NaN                 NaN
# 78         White/Caucasian                    NaN          Unemployed
# 82  Asian/Pacific Islander                    NaN  Employed full-time
#
#     number_children  political_affiliation
# 17              NaN               Democrat
# 53                1         No affiliation
# 63              NaN                    NaN
# 78                1               Democrat
# 82              NaN               Democrat
#
# [5 rows x 57 columns]

# %%
# Out:
#    submission_id              age         cups  \
# 34        ylqbBg  45-54 years old            2
# 41        YZzBdN  25-34 years old            2
# 42        VZ17Z6  35-44 years old            1
# 43        RzBeZj  45-54 years old  More than 4
# 46        WApbkQ  35-44 years old            2
#
#                                      where_drink  \
# 34  At home, At the office, At a cafe, On the go
# 41                        At home, At the office
# 42                        At the office, At home
# 43                                       At home
# 46                            At a cafe, At home
#
#                                                  brew brew_other  \
# 34                  Pour over, French press, Espresso        NaN
# 41                                Pour over, Espresso        NaN
# 42                                          Pour over        NaN
# 43  Pour over, French press, Pod/capsule machine (...        NaN
# 46  Espresso, Pod/capsule machine (e.g. Keurig/Nes...        NaN
#
#                              purchase purchase_other             favorite  \
# 34  Local cafe, Specialty coffee shop            NaN  Regular drip coffee
# 41                                NaN            NaN             Pourover
# 42                                NaN            NaN          Iced coffee
# 43                                NaN            NaN             Pourover
# 46                                NaN            NaN           Cappuccino
#
#    favorite_specify  ...   spent_equipment value_equipment gender  \
# 34              NaN  ...        $500-$1000             Yes   Male
# 41              NaN  ...          $50-$100             Yes   Male
# 42              NaN  ...         $100-$300             Yes   Male
# 43              NaN  ...         $300-$500             Yes   Male
# 46              NaN  ...  More than $1,000             Yes   Male
#
#    gender_specify        education_level          ethnicity_race  \
# 34            NaN        Master's degree  Other (please specify)
# 41            NaN        Master's degree  Asian/Pacific Islander
# 42            NaN      Bachelor's degree         White/Caucasian
# 43            NaN      Bachelor's degree         White/Caucasian
# 46            NaN  Less than high school  Black/African American
#
#    ethnicity_race_specify   employment_status  number_children  \
# 34                    Mix  Employed full-time                2
# 41                    NaN          Unemployed              NaN
# 42                    NaN  Employed full-time                3
# 43                    NaN  Employed full-time                3
# 46                    NaN          Unemployed                2
#
#     political_affiliation
# 34         No affiliation
# 41            Independent
# 42         No affiliation
# 43         No affiliation
# 46            Independent
#
# [5 rows x 57 columns]

# %% [markdown]
# 11. Realice un gráfico de torta que muestre el porcentaje de consumidores pertenecientes a cada grupo etario.

# %%
import matplotlib.pyplot as plt

# 11. Gráfico de grupos etarios

# %% [markdown]
# 12. Realice un gráfico de barras para cada grupo etario, mostrando cuántos consumidores prefieren cada tipo de café.
#
#     **Ayuda**: investigue los métodos  `size` y `unstack`. Puede usar una estructura de repetición for para la creación de los gráficos, que le permita en cada iteración graficar la información correspondiente a cada grupo etario.

# %%
# 12. Gráfico de café favorito por grupos etarios

# %% [markdown]
# 13. Calcule el nivel educativo más frecuente entre los consumidores que respondieron la encuesta.
#
#     **Ayuda:** Puede usar `groupby` o investigar `mode`.

# %%
# Nivel educativo más frecuente
# Out:
# El nivel educativo más frecuente es: Bachelor's degree

# %% [markdown]
# **13-** **Conclusiones:**
#
# Realice un análisis exhaustivo de los datos cargados en el `DataFrame` llamado `encuesta` recién creado. ¿Qué información relevante se puede extraer? Puede ayudarse de los gráficos o imprimir en pantalla información de este `DataFrame`. Reflexione sobre las conclusiones que se pueden obtener a partir de esta información.
#
# Además, ¿qué recomendaciones ofrecería a su cliente para optimizar su cafetería? Por ejemplo, ¿a qué segmentos de clientes debería orientar su campaña de marketing para maximizar el impacto y atraer a más consumidores?

# %% [markdown]
# *Complete aquí sus conclusiones*
